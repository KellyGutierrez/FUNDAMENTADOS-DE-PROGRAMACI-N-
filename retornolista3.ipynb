# %%
def cargar_datos():
    nom=[]
    ed=[]
    for x in range(5):
        v1=input("Ingrese el nombre de la persona:")
        nom.append(v1)
        v2=int(input("Ingrese la edad:"))
        ed.append(v2)
    return [nom,ed]


def mayores_edad(nom,ed):
    print("Nombres de personas mayores de edad")
    for x in range(len(nom)):
        if ed[x]>=18:
            print(nom[x])


def promedio_edades(ed):
    suma=0
    for x in range(len(ed)):
        suma=suma+ed[x]
    promedio=suma//5
    print("Edad promedio de las personas:",promedio)
    

# bloque principal

nombres,edades=cargar_datos()
mayores_edad(nombres,edades)
promedio_edades(edades)
# Out:
# Ingrese el nombre de la persona:kelly
# Ingrese la edad:17
# Ingrese el nombre de la persona:maximiliano
# Ingrese la edad:18
# Ingrese el nombre de la persona:mateo
# Ingrese la edad:15
# Ingrese el nombre de la persona:daniela
# Ingrese la edad:16
# Ingrese el nombre de la persona:daniel
# Ingrese la edad:17
# Nombres de personas mayores de edad
# maximiliano
# Edad promedio de las personas: 16
